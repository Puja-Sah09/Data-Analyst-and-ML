# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("world_population.csv")

# %%
df.head()
# Out:
#    Rank CCA3 Country/Territory           Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan             Kabul      Asia         41128771
# 1   138  ALB           Albania            Tirana    Europe          2842321
# 2    34  DZA           Algeria           Algiers    Africa         44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania            44273
# 4   203  AND           Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
df.shape
# Out:
# (234, 17)

# %%
df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country/Territory', 'Capital', 'Continent',
#        '2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population', '1990 Population',
#        '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
#        'Growth Rate', 'World Population Percentage'],
#       dtype='object')

# %% [markdown]
# Data Quality

# %%
df.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country/Territory              0
# Capital                        0
# Continent                      0
# 2022 Population                0
# 2020 Population                0
# 2015 Population                0
# 2010 Population                0
# 2000 Population                0
# 1990 Population                0
# 1980 Population                0
# 1970 Population                0
# Area (km²)                     0
# Density (per km²)              0
# Growth Rate                    0
# World Population Percentage    0
# dtype: int64

# %% [markdown]
# This shows data has no null values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Exploratory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %%
df.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.407441e+07     3.350107e+07     3.172996e+07
# std     67.694165     1.367664e+08     1.355899e+08     1.304050e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.152845e+05     4.046760e+05
# 50%    117.500000     5.559944e+06     5.493074e+06     5.307400e+06
# 75%    175.750000     2.247650e+07     2.144798e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      2.984524e+07     2.626947e+07     2.271022e+07     1.898462e+07
# std       1.242185e+08     1.116982e+08     9.783217e+07     8.178519e+07
# ...

# %% [markdown]
# Population Growth over Time

# %%
years = ['1970 Population', '1980 Population', '1990 Population', '2000 Population', '2010 Population', '2015 Population', '2020 Population', '2022 Population']
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(14, 16))
axes = axes.flatten()

for i, year in enumerate(years):
    axes[i].bar(df['Country/Territory'].head(10), df[year].head(10), color='skyblue')
    axes[i].set_title(f'Population in {year}')
    axes[i].tick_params(axis='x', rotation=90)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

df.set_index('Country/Territory', inplace=True)

# List of years for which we have population data
years = ['1970 Population', '1980 Population', '1990 Population', '2000 Population', 
         '2010 Population', '2015 Population', '2020 Population', '2022 Population']

# Plot population growth over time for a selection of countries
countries_to_plot = df.sample(n=10, random_state=42)  # Select 10 random countries

plt.figure(figsize=(14, 8))
for country in countries_to_plot.index:
    plt.plot(years, [df.loc[country, year] for year in years], marker='o', label=country)

plt.xticks(rotation=45)
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Population Growth Over Time for Selected Countries')
plt.legend(title='Country/Territory')
plt.tight_layout()
plt.show()

# %% [markdown]
# Graph shows that Indonesia has great increase in the population over time where contries like Baharin has constant population over time

# %% [markdown]
# Population Distribution by Continent

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='Continent', y='2022 Population')
plt.title('Population Distribution by Continent (2022)')
plt.xlabel('Continent')
plt.ylabel('2022 Population')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Area vs Population distribution

# %%
plt.figure(figsize=(12, 6))
plt.scatter(df['Area (km²)'], df['2022 Population'], alpha=0.5)
plt.xscale('log')
plt.yscale('log')
plt.title('Area vs. 2022 Population (Log Scale)')
plt.xlabel('Area (km²)')
plt.ylabel('2022 Population')
plt.show()

# %% [markdown]
# Distribution of Population Growth Rate

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Growth Rate'], kde=True, bins=30)
plt.title('Distribution of Population Growth Rate')
plt.xlabel('Growth Rate')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df['Growth Rate'].describe()
# Out:
# count    234.000000
# mean       1.009577
# std        0.013385
# min        0.912000
# 25%        1.001775
# 50%        1.007900
# 75%        1.016950
# max        1.069100
# Name: Growth Rate, dtype: float64

# %% [markdown]
# The data of growth rate is left skewed which means that average growth rate is more than the overall

# %% [markdown]
# Population Distribution

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df, x='Density (per km²)', y='Growth Rate')
plt.title('Growth Rate vs. Population Density')
plt.xlabel('Density (per km²)')
plt.ylabel('Growth Rate')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df, x='Area (km²)', y='2022 Population')
plt.title('Total Population vs. Area')
plt.xlabel('Area (km²)')
plt.ylabel('2022 Population')
plt.show()

# %% [markdown]
# Question 1 : country with the largest population in 2022

# %%
coun = df.loc[df['Country/Territory'].idxmax()]
print(f'The Country with largest popolation is :')
print(coun)
# Out:
# The Country with largest popolation is :
# Rank                                 74
# CCA3                                ZWE
# Country/Territory              Zimbabwe
# Capital                          Harare
# Continent                        Africa
# 2022 Population                16320537
# 2020 Population                15669666
# 2015 Population                14154937
# 2010 Population                12839771
# 2000 Population                11834676
# 1990 Population                10113893
# 1980 Population                 7049926
# 1970 Population                 5202918
# Area (km²)                       390757
# Density (per km²)               41.7665
# Growth Rate                      1.0204
# World Population Percentage         0.2
# Name: 233, dtype: object

# %% [markdown]
# Question 2 : Average population growth rate across all countries

# %%
pop_rate = df['Growth Rate'].mean()
print(f'The average population growth rate across all countries is {pop_rate}')
# Out:
# The average population growth rate across all countries is 1.0095773504273504

# %% [markdown]
# total area of all countries combined

# %%
total_area = df['Area (km²)'].sum()
print(f"The total area of all countries combined is {total_area:,.0f} km².")
# Out:
# The total area of all countries combined is 136,059,156 km².

# %% [markdown]
# Question 3 : Continent with highest average population

# %%
avg_population_by_continent = df.groupby('Continent')['2022 Population'].mean()
continent_highest_population = avg_population_by_continent.idxmax()
highest_population = avg_population_by_continent.max()
print(f"The continent with the highest average population in 2022 is {continent_highest_population} with an average population of {highest_population:,.0f}.")
# Out:
# The continent with the highest average population in 2022 is Asia with an average population of 94,427,665.

# %% [markdown]
# Question 4 : Distribution of the population of the top 5 most populous countries over the last 50 years

# %%
top_5_countries = df.nlargest(5, '2022 Population')
plt.figure(figsize=(14, 8))
for country in top_5_countries['Country/Territory']:
    plt.plot(years, top_5_countries[top_5_countries['Country/Territory'] == country][years].values.flatten(), marker='o', label=country)
plt.xticks(rotation=45)
plt.title('Population Growth Over Time for Top 5 Most Populous Countries')
plt.xlabel('Year')
plt.ylabel('Population')
plt.legend()
plt.show()

# %% [markdown]
# Question 5 : relationship between area and population for the most populous countries

# %%
most_populous_countries = df.nlargest(10, '2022 Population')
plt.figure(figsize=(12, 6))
sns.scatterplot(data=most_populous_countries, x='Area (km²)', y='2022 Population', hue='Country/Territory', palette='viridis', s=100)
plt.title('Area vs. Population for Most Populous Countries')
plt.xlabel('Area (km²)')
plt.ylabel('2022 Population')
plt.show()

# %% [markdown]
# Question 6 : countries that have experienced the highest population growth rate in the last 10 years

# %%
recent_growth_rate = df['Growth Rate'].sort_values(ascending=False).head(10)
print("Countries with the highest population growth rate in the last 10 years:")
print(recent_growth_rate)
# Out:
# Countries with the highest population growth rate in the last 10 years:
# 133    1.0691
# 164    1.0404
# 148    1.0378
# 202    1.0376
# 189    1.0359
# 55     1.0325
# 130    1.0319
# 39     1.0316
# 5      1.0315
# 124    1.0314
# Name: Growth Rate, dtype: float64

# %% [markdown]
# Question 7 : population trends of continent over the decades

# %%
continent_population_trends = df.groupby('Continent')[years].mean().T
continent_population_trends.plot(figsize=(14, 8))
plt.title('Average Population Trends by Continent')
plt.xlabel('Year')
plt.ylabel('Average Population')
plt.legend(title='Continent')
plt.show()

# %% [markdown]
# Question 8 : percentage of the world’s population each country represent in 2022

# %%
total_world_population = df['2022 Population'].sum()
df['World Population Percentage'] = (df['2022 Population'] / total_world_population) * 100
print(df[['Country/Territory', 'World Population Percentage']].sort_values(by='World Population Percentage', ascending=False))
# Out:
#     Country/Territory  World Population Percentage
# 41              China                    17.883024
# 92              India                    17.773733
# 221     United States                     4.242723
# 93          Indonesia                     3.455250
# 156          Pakistan                     2.957640
# ..                ...                          ...
# 137        Montserrat                     0.000055
# 64   Falkland Islands                     0.000047
# 150              Niue                     0.000024
# 209           Tokelau                     0.000023
# 226      Vatican City                     0.000006
#
# [234 rows x 2 columns]

# %% [markdown]
# Key Findings¶
# ## Largest Population: The country with the largest population in 2022 is China, followed closely by India.
#
# ## Average Growth Rate: The average population growth rate across all countries is relatively modest, with significant variations between countries and regions.
#
# ## Population Density: Asia has some of the highest population densities, with countries like Bangladesh and Singapore being densely populated.
#
# ## Total Area: The total area of all countries combined provides a sense of the geographical scale considered in the dataset.
#
# ## Highest Average Population: Asia, being the most populous continent, has the highest average population.
#
# ## Population Growth Over Time: The top 5 most populous countries have shown significant population growth over the last 50 years, with notable increases in India, Nigeria, and the United States.
#
# ## Area vs. Population: There is a diverse relationship between area and population, with some large countries like Russia having relatively low population densities.
# High Growth Rates: Some countries, particularly in Africa and the Middle East, have experienced the highest population growth rates in recent years.
#
# ## Population Trends by Continent: Population trends vary significantly by continent, with Africa and Asia showing rapid growth, while Europe has relatively stable or declining populations.
#
# ## World Population Percentage: Countries like China and India constitute a significant portion of the world’s population, each representing over 15% of the global population.

# %% [markdown]
# DATA VISUALIZATION

# %%
continent_df = df.groupby(by='Continent').sum()
altered_continent_df = continent_df.drop(columns=["CCA3", "Country/Territory", "Rank", "Capital", "Growth Rate", "Area (km²)", "Density (per km²)","World Population Percentage"])
altered_continent_df.head()
# Out:
#                2022 Population  2020 Population  2015 Population  \
# Continent
# Africa              1426730932       1360671810       1201102442
# Asia                4721383274       4663086535       4458250182
# Europe               743147538        745792196        741535608
# North America        600296136        594236593        570383850
# Oceania               45038554         43933426         40403283
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Africa              1055228072        818946032        638150629
# Asia                4220041327       3735089604       3210563577
# Europe               735613934        726093423        720320797
# North America        542720651        486069584        421266425
# Oceania               37102764         31222778         26743822
#
#                1980 Population  1970 Population
# Continent
# Africa               481536377        365444348
# Asia                2635334228       2144906290
# ...

# %%
transposed = altered_continent_df.T
transposed.index = transposed.index.str.replace(" Population", "")
transposed.sort_index().plot.line(title="Population over the years", legend=True)
# Out:
# <Axes: title={'center': 'Population over the years'}>

# %%
# Asia
asian_countries = df.loc[df["Continent"]=="Asia"].sort_values(by=["2022 Population"], ascending=False, ignore_index=True)

# Africa
african_countries = df.loc[df["Continent"]=="Africa"].sort_values(by=["2022 Population"], ascending=False, ignore_index=True)

# Europe
european_countries = df.loc[df["Continent"]=="Europe"].sort_values(by=["2022 Population"], ascending=False, ignore_index=True)

# North America
na_countries = df.loc[df["Continent"]=="North America"].sort_values(by=["2022 Population"], ascending=False, ignore_index=True)

# Oceania
oc_countries = df.loc[df["Continent"]=="Oceania"].sort_values(by=["2022 Population"], ascending=False, ignore_index=True)

# South America
sa_countries = df.loc[df["Continent"]=="South America"].sort_values(by=["2022 Population"], ascending=False, ignore_index=True)

# %%
top_5_countries = asian_countries[["Country/Territory", "2022 Population"]].sort_values(by="2022 Population", ascending=False).head(5)

top_5_countries.set_index("Country/Territory", inplace=True)

top_5_countries.plot.pie(y="2022 Population", autopct='%1.1f%%', legend=False)
# Out:
# <Axes: ylabel='2022 Population'>

# %%
top_5_countries = african_countries[["Country/Territory", "2022 Population"]].sort_values(by="2022 Population", ascending=False).head(5)

top_5_countries.set_index("Country/Territory", inplace=True)

top_5_countries.plot.pie(y="2022 Population", autopct='%1.1f%%', legend=False)
# Out:
# <Axes: ylabel='2022 Population'>

# %%
top_5_countries = european_countries[["Country/Territory", "2022 Population"]].sort_values(by="2022 Population", ascending=False).head(5)

top_5_countries.set_index("Country/Territory", inplace=True)

top_5_countries.plot.pie(y="2022 Population", autopct='%1.1f%%', legend=False)
# Out:
# <Axes: ylabel='2022 Population'>

# %%
top_5_countries = na_countries[["Country/Territory", "2022 Population"]].sort_values(by="2022 Population", ascending=False).head(5)

top_5_countries.set_index("Country/Territory", inplace=True)

top_5_countries.plot.pie(y="2022 Population", autopct='%1.1f%%', legend=False)
# Out:
# <Axes: ylabel='2022 Population'>

# %%
top_5_countries = oc_countries[["Country/Territory", "2022 Population"]].sort_values(by="2022 Population", ascending=False).head(5)

top_5_countries.set_index("Country/Territory", inplace=True)

top_5_countries.plot.pie(y="2022 Population", autopct='%1.1f%%', legend=False)
# Out:
# <Axes: ylabel='2022 Population'>

# %%
top_5_countries = sa_countries[["Country/Territory", "2022 Population"]].sort_values(by="2022 Population", ascending=False).head(5)

top_5_countries.set_index("Country/Territory", inplace=True)

top_5_countries.plot.pie(y="2022 Population", autopct='%1.1f%%', legend=False)
# Out:
# <Axes: ylabel='2022 Population'>

# %% [markdown]
#  Correalation Heatmap¶
# Here are the questions that need to be answered for this section again.
#
# Predictive Analysis
# Is there any correalation with Area and Populaion?

# %%
sns.set(rc = {"figure.figsize":(10,10)})

Numeric_Only = df[['Area (km²)','Density (per km²)',
                   'Growth Rate', '2022 Population' ]]

Correlation = Numeric_Only.corr()
Correlation_Graph = sns.heatmap(Correlation, annot = True).set(title = 'Correlation Heatmap of Selected Numeric Variables')

# %% [markdown]
# Key Insights from the graph above:¶
# * When the Area of Country increases, so does the Population of that country.
# * Area and Density are negatively correlated as when Area of a Country increases, the density of the population decreases.

# %%
sns.catplot(data = df, x = 'Continent', y = 'Growth Rate', kind = "box", aspect = 1.75).set(title = 'Boxplot of World Population Growth by Continent')
plt.show()

# %% [markdown]
# Key Insights from the graph above:¶
# * Africa has the highest average Growth Rate at 1.02 with Asia second at 1.009.
# * Europe has the lowest average Growth Rate while having lots of outliers.

# %% [markdown]
# Data Engg

# %%
df['GrowthRate'] = df['2022 Population'].pct_change() * 100
df = df.dropna()

# %%
features = ['2020 Population', '2015 Population', '2010 Population', 'Area (km²)', 'Density (per km²)', 'Growth Rate']
X = df[features]
y = df['2022 Population']  # Target variable to predict

# %%
from sklearn.preprocessing import OneHotEncoder

# Example: One-hot encode the 'Continent' column
df = pd.get_dummies(df, columns=['Continent'], drop_first=True)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# Initialize the model
model = LinearRegression()

# Train the model
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'MSE: {mse}')
print(f'R²: {r2}')
# Out:
# MSE: 465951821511.8721
# R²: 0.9998451339575136
